# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/민철 포트폴리오/포스코 아카데미/POSCO-AI-BIGDATA-19th
# Out:
# /content/drive/MyDrive/민철 포트폴리오/포스코 아카데미/POSCO-AI-BIGDATA-19th
